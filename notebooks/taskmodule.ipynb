# %%
from pie_datasets import load_dataset

from src.taskmodules import AMTaskModule

dataset = load_dataset("pie/cdcp")
documents = dataset["test"][:3]
tm = AMTaskModule("allenai/longformer-base-4096")

# %%
documents

# %%
encoded = tm.encode_input(documents[0])

# %%
encoded[0].metadata["tokenizer_encoding"].ids
